# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../datasets/price_datasets/cleaned_combined_price_data.csv')

# Get unique zipcodes
unique_zipcodes = df['ZIPCODE'].unique()

# Display the results
print(f"Number of unique zipcodes: {len(unique_zipcodes)}")
print("\nUnique zipcodes:")
print(sorted(unique_zipcodes))
# Out:
# Number of unique zipcodes: 33
#
# Unique zipcodes:
# [np.int64(2026), np.int64(2108), np.int64(2109), np.int64(2110), np.int64(2111), np.int64(2113), np.int64(2114), np.int64(2115), np.int64(2116), np.int64(2118), np.int64(2119), np.int64(2120), np.int64(2121), np.int64(2122), np.int64(2124), np.int64(2125), np.int64(2126), np.int64(2127), np.int64(2128), np.int64(2129), np.int64(2130), np.int64(2131), np.int64(2132), np.int64(2134), np.int64(2135), np.int64(2136), np.int64(2199), np.int64(2210), np.int64(2215), np.int64(2445), np.int64(2446), np.int64(2458), np.int64(2467)]
# /var/folders/6c/9skhv5gd3dd6z1g2y4xnf3140000gn/T/ipykernel_56668/2854795649.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../datasets/price_datasets/cleaned_combined_price_data.csv')
